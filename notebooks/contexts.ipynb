# %%
import sys
sys.path.insert(0, '../')
import pycor

data_dir = "../samples"
outputpath = "../../output/samples/"
model_path = outputpath + "model"

print(pycor.version())
# Out:
# Init Trainer
# Init DocResolver
# 0.0.6

# %%
pycor.registerKeyword('시카고','NN')

words_array, tags_array = pycor.trimfile(data_dir+"/docs/economics1.txt")

for row in range(len(words_array)):
    words = words_array[row]
    print(words)
#     tags = tags_array[row]
#     for col in range(len(words)):
#         print(words[col], tags[col], end="  ") 
#     print()
# Out:
# ['통화', '정책', '通貨', '政策', '또는', '화폐', '정책', '貨幣', '政策', '정부', '중앙은행', '등', '한', '국가', '화폐', '공급', '유용성', '화폐가치', '금리', '등', '경제', '성장', '안정성', '유지', '하', '수행하', '일련', '조치', '일컫', '말']
# ['1', '일반적', '통화', '이론', '화폐', '개혁', '가장', '기초적', '정통하', '대책', '여겨지']
# ['통화량', '조절', '위하', '정부', '중앙은행', '공개시장조작', '재할인율', '지급준비율', '조정하', '수단', '사용하']
# ['화폐', '정책', '대개', '팽창적', '화폐정책', '긴축적', '화폐정책', '규정되', '말그', '팽창', '꾀하', '정책', '화폐', '공급', '늘리', '것', '수축', '정책', '정반대', '원칙', '고수하']
# ['화폐', '공급', '늘', '시', '금리', '내리', '실업률', '줄어들', '돕', '것', '말하', '반대', '상황시', '금리이자율', '올려', '인플레이션', '억제하', '한']
# ['대개', '화폐', '정책', '일국', '국', '상황', '대치되', '운영되', '정부', '세입', '여', '지출', '모두', '고려해야하', '때문']
# ['화폐공급', '변화', '유동성', '효과', '소득', '효과', '피셔', '효과', '시차적', '나타내', '금리', '영향', '준']
# ['신용화폐']
# ['금은', '소재가치', '의거하', '주조되', '본위화폐', '기능', '보충하', '보조화폐', '생겨나']
# ['소액', '본위화폐', '주조', '양', '적어지', '기술적', '곤란하', '결', '금', '이외', '동', '銅', '알미늄', '니켈', '주석', '등', '소재', '선정되어', '보조화폐', '주조되']
# ...
